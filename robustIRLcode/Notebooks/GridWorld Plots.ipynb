# %%
import sys
sys.path.insert(0,'../CompareAlphas/')
sys.path.insert(0,'../VisualizePolicy')
sys.path.insert(0,'../src/')
from CompareAlphas_loader import CompareAlphas_loader
from plot import plot_reward
from environment import GridWorldEnvironment

# %% [markdown]
# # Visualize the reward structure

# %%
dim =10 # 10 for env_type 0,1,2,9. 6 for env_type 10"
env_type = 2 # Available Options: 0, 1, 2, 9, 10"
noiseL = 0.1 # Available 0.0 0.05 0.1
env = GridWorldEnvironment(env_type, dim)
plot_reward(env.state_r, dim, title = "", show = False)
# Out:
# 100
# [-100.5  -99.5   -0.5    0.5]

# %% [markdown]
# # Baseline Comparison

# %%
CompareAlphas_loader(dim = dim, env_type = env_type, noiseL = noiseL, low_alpha = True, include_iil = True, legend = True, alphas = ["1.0", "0.8"], end_title="presentation")

# %% [markdown]
# # Alpha ablation

# %%
CompareAlphas_loader(dim = dim, env_type = env_type, noiseL = noiseL, low_alpha = False, include_iil = False, end_title = "ablation")
