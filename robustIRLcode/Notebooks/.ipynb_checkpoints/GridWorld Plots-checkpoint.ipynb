# %%
import sys
sys.path.insert(0,'../CompareAlphas/')
sys.path.insert(0,'../VisualizePolicy')
sys.path.insert(0,'../src/')
from CompareAlphas_loader import CompareAlphas_loader
from plot import plot_reward
from environment import GridWorldEnvironment

# %% [markdown]
# # Visualize the reward structure

# %%
dim =10 # 10 for env_type 0,1,2,9. 6 for env_type 10"
env_type = 9 # Available Options: 0, 1, 2, 9, 10"
env = GridWorldEnvironment(env_type, dim)
plot_reward(env.state_r, dim, title = "", show = True)
# Out:
# 100
# [-100.5  -99.5   -0.5    0.5]

# %% [markdown]
# # Learner Noise 0.0

# %%
CompareAlphas_loader(dim = 10, env_type = 0, noiseL = 0.0, low_alpha = False, include_iil = True)

# %%
CompareAlphas_loader(dim = 10, env_type = 1, noiseL = 0.0, low_alpha = False, include_iil = True)

# %%
CompareAlphas_loader(dim = 10, env_type = 2, noiseL = 0.0, low_alpha = False, include_iil = True)

# %%
CompareAlphas_loader(dim = 10, env_type = 9, noiseL = 0.0, low_alpha = False, include_iil = True)

# %%
CompareAlphas_loader(dim = 6, env_type = 10, noiseL = 0.0, low_alpha = False, include_iil = True)

# %% [markdown]
# # Learner Noise 0.05

# %%
CompareAlphas_loader(dim = 10, env_type = 0, noiseL = 0.05, low_alpha = False, include_iil = True)

# %%
CompareAlphas_loader(dim = 10, env_type = 1, noiseL = 0.05, low_alpha = False, include_iil = False)

# %%
CompareAlphas_loader(dim = 10, env_type = 2, noiseL = 0.05, low_alpha = False, include_iil = True)

# %%
CompareAlphas_loader(dim = 10, env_type = 9, noiseL = 0.05, low_alpha = False, include_iil = True)

# %%
CompareAlphas_loader(dim = 6, env_type = 10, noiseL = 0.05, low_alpha = False, include_iil = True)

# %% [markdown]
# # Learner Noise 0.1

# %%
CompareAlphas_loader(dim = 10, env_type = 0, noiseL = 0.1, low_alpha = False, include_iil = True)

# %%
CompareAlphas_loader(dim = 10, env_type = 1, noiseL = 0.1, low_alpha = False, include_iil = False)

# %%
CompareAlphas_loader(dim = 10, env_type = 2, noiseL = 0.1, low_alpha = False, include_iil = True)
