# %%
import sys
sys.path.insert(0,'../CompareAlphas/')
sys.path.insert(0,'../VisualizePolicy')
sys.path.insert(0,'../src/')
from CompareAlphas_ow_loader import CompareAlphas_ow_loader
from plot import plot_objectworld
from environment import ObjectWorldEnvironment

# %% [markdown]
# # Visualize the reward structure

# %%
dim = 10
n_objects = 6
n_colours = 2
noiseL = 0.05
env_seed = 10 #Seed for random object placement
ObjectWorld = ObjectWorldEnvironment(dim, n_objects, n_colours, env_seed)
plot_objectworld(ObjectWorld, dim, title = " ", log_color = False, show = False)
# Out:
# 100
# ['blue', 'green']
# X
# [9, 7, 8, 3, 2, 4]
# Y
# [7, 7, 0, 1, 6, 6]

# %% [markdown]
# # Learner Noise 0.0

# %% [markdown]
# # Learner Noise 0.0

# %%
CompareAlphas_ow_loader(dim = 10, env_seed = 10, noiseL = noiseL, fix_horizon = False, low_alpha = False, include_iil = False, legend = True, alphas = ["1.0", "0.9"], end_title = "presentation")

# %% [markdown]
# # Learner Noise 0.05

# %%
CompareAlphas_ow_loader(dim = 10, env_seed = 10, noiseL = 0.05, fix_horizon = False, low_alpha = True, include_iil = False, legend= False)

# %%
CompareAlphas_ow_loader(dim = 10, env_seed = 10, noiseL = 0.1, fix_horizon = False, low_alpha = True, include_iil = True, legend= False, alphas = ["1.0", "0.9"], end_title = "presentation")

# %%
CompareAlphas_ow_loader(dim = 10, env_seed = 10, noiseL = 0.05, fix_horizon = False, low_alpha = True, include_iil = True, legend= False, alphas = ["1.0", "0.9"], end_title = "presentation")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-e4c1dd983c17> in <module>
# ----> 1 CompareAlphas_ow_loader(dim = 10, env_seed = 10, noiseL = 0.05, fix_horizon = False, low_alpha = True, include_iil = True, legend= False, alphas = ["1.0", "0.9"], end_title = "presentation")
#
# ~\Desktop\Inverse_Reinforcement_Learning\robustIRLcode\CompareAlphas\CompareAlphas_ow_loader.py in CompareAlphas_ow_loader(dim, env_seed, noiseL, fix_horizon, low_alpha, include_iil, legend, alphas, end_title)
#      53     if include_iil:
#      54         lr_iil = 0.01
# ---> 55         data = load_result( "IIL_OW_CompareAlphas_env" + str(env_seed) + "size" + str(dim)+"lr"+str(lr_iil)+noiseL+"fix_start"+str(fix_start))
#      56         Vs_to_plot.append(data["Vs_to_plot"][0])
#      57         sigma_Vs_to_plot.append(data["sigma_Vs"][0])
#
# ...

# %% [markdown]
# # Learner Noise 0.1

# %%
CompareAlphas_ow_loader(dim = 10, env_seed = 10, noiseL = 0.1, fix_horizon = False, low_alpha = True, include_iil = False, legend = False)

# %%
CompareAlphas_ow_loader(dim = 10, env_seed = 10, noiseL = 0.1, fix_horizon = False, low_alpha = True, include_iil = False, legend= True, alphas = ["1.0", "0.9"], end_title = "presentation")
