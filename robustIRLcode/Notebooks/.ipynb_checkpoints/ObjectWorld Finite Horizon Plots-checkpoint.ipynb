# %%
import sys
sys.path.insert(0,'../CompareAlphas/')
sys.path.insert(0,'../VisualizePolicy')
sys.path.insert(0,'../src/')
from CompareAlphas_ow_loader import CompareAlphas_ow_loader
from plot import plot_objectworld
from environment import ObjectWorldEnvironment

# %% [markdown]
# # Visualize the reward structure

# %%
dim = 10
n_objects = 6
n_colours = 2
env_seed = 10 #Seed for random object placement
ObjectWorld = ObjectWorldEnvironment(dim, n_objects, n_colours, env_seed)
plot_objectworld(ObjectWorld, dim, title = " ", log_color = False, show = True)
# Out:
# 100
# ['blue', 'green']
# X
# [9, 7, 8, 3, 2, 4]
# Y
# [7, 7, 0, 1, 6, 6]

# %% [markdown]
# # Learner Noise 0.0

# %%
CompareAlphas_ow_loader(dim = 10, env_seed = 10, noiseL = 0.0, fix_horizon = True, low_alpha = False)

# %% [markdown]
# # Learner Noise 0.05

# %%
CompareAlphas_ow_loader(dim = 10, env_seed = 10, noiseL = 0.05, fix_horizon = True, low_alpha = False)

# %% [markdown]
# # Learner Noise 0.1

# %%
CompareAlphas_ow_loader(dim = 10, env_seed = 10, noiseL = 0.1, fix_horizon = True, low_alpha = False)
