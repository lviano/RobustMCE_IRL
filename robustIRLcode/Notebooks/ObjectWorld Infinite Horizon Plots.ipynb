# %%
import sys
sys.path.insert(0,'../CompareAlphas/')
sys.path.insert(0,'../VisualizePolicy')
sys.path.insert(0,'../src/')
from CompareAlphas_ow_loader import CompareAlphas_ow_loader
from plot import plot_objectworld
from environment import ObjectWorldEnvironment

# %% [markdown]
# # Visualize the reward structure

# %%
dim = 10
n_objects = 6
n_colours = 2
noiseL = 0.1
env_seed = 10 #Seed for random object placement
ObjectWorld = ObjectWorldEnvironment(dim, n_objects, n_colours, env_seed)
plot_objectworld(ObjectWorld, dim, title = " ", log_color = False, show = False)
# Out:
# 100
# ['blue', 'green']
# X
# [9, 7, 8, 3, 2, 4]
# Y
# [7, 7, 0, 1, 6, 6]

# %% [markdown]
# # Baseline Comparison

# %%
CompareAlphas_ow_loader(dim = 10, env_seed = 10, noiseL = noiseL, fix_horizon = False, low_alpha = False, include_iil = False, legend = True, alphas = ["1.0", "0.9"], end_title = "presentation")

# %% [markdown]
# # Ablation

# %%
CompareAlphas_ow_loader(dim = 10, env_seed = 10, noiseL = noiseL, fix_horizon = False, low_alpha = True, include_iil = False, legend= False)
