# %%
import sys
sys.path.insert(0,'../CompareAlphas/')
sys.path.insert(0,'../VisualizePolicy')
sys.path.insert(0,'../src/')
from CompareAlphas_tdw_loader import CompareAlphas_tdw_loader
from plot import plot_reward
from environment import TwoDangerEnvironment

# %% [markdown]
# # Visualize the reward structure

# %%
dim =10 #No other available options
env_type = 1 #No other available options
noiseL = 0.0 # Choices: 0.0 0.05 0.1
env = TwoDangerEnvironment(env_type, dim)
plot_reward(env.state_r, dim, title = "", tdw = True, show = True)
# Out:
# 100
# [-6.5 -5.5 -1.5 -0.5  0.5]

# %% [markdown]
# # Ablation

# %%
CompareAlphas_tdw_loader(dim = 10, env_type = 1, noiseL = noiseL, low_alpha = False)

# %% [markdown]
# # Baseline Comparison

# %%
CompareAlphas_tdw_loader(dim = 10, env_type = 1, noiseL = noiseL, low_alpha = False, alphas = ["1.0",  "0.8"], end_title = "presentation")
